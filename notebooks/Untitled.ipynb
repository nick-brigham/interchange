# %%
import pandas as pd

results = pd.read_csv('../data/processed/rag_finetuned_results.csv')

print(results[['customer_description', 'part_number', 'predicted']].head(20))
print(f"\nSample of wrong predictions:")
wrong = results[results['predicted'].str.upper() != results['part_number'].str.upper()]
print(wrong[['customer_description', 'part_number', 'predicted']].head(20))
# Out:
#                    customer_description   part_number     predicted
# 0                      290XL037  V-BELT      290XL037      290XL037
# 1                 BX 50 TRI-POWER® BELT          BX50          BX50
# 2        8MGT-1000-12  POLY CHAIN® BELT  8MXT-1000-12  8MXT-1000-12
# 3                         B42 VB V-BELT           B42           B42
# 4                     2005M06 HTD® BELT      200-5M-6     2005-5M-6
# 5                 A 77 HI-POWER® V BELT           A77           A77
# 6                              1500H300      1500H300      1500H300
# 7                5VX840 SUPER HC V-BELT        5VX840        5VX840
# 8                  5/5VX1120 POWERBAND®    R5VX1120-5    R5VX1120-5
# 9                  560H150  TIMING BELT       560H150       560H150
# 10       8MGT-896-21   POLY CHAIN® BELT   8MXT-896-21   8MXT-896-21
# 11                 4/5VX1400 POWERBAND®    R5VX1400-4    R5VX1400-4
# 12                  1760-8M-85 HTD BELT    1760-8M-85    1760-8M-85
# ...
